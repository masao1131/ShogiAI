# %%
#Pythonのバージョン確認
import sys
sys.version
# Out:
# '3.13.1 (main, Jan 14 2025, 22:47:35) [MSC v.1942 64 bit (AMD64)]'

# %%
import torch

# GPU(CUDA)が利用可能かチェック
is_available = torch.cuda.is_available()
print(f"GPU利用可能: {is_available}")

if is_available:
    print(f"GPUデバイス名: {torch.cuda.get_device_name(0)}")
    print(f"現在のデバイス番号: {torch.cuda.current_device()}")
# Out:
# GPU利用可能: True
# GPUデバイス名: NVIDIA GeForce RTX 4050 Laptop GPU
# 現在のデバイス番号: 0

# %%
# 環境のパス
print(f"作業環境：{sys.executable}")
# PyTorchのパス
print(f"PyTorchのパス：{torch.__file__}")
# PyTorchのバージョン
print(f"PyTorchのバージョン: {torch.__version__}")
# Out:
# 作業環境：c:\Users\m45_o\Desktop\my_python\strong_syogi\.venv\Scripts\python.exe
# PyTorchのパス：c:\Users\m45_o\Desktop\my_python\strong_syogi\.venv\Lib\site-packages\torch\__init__.py
# PyTorchのバージョン: 2.10.0+cu128
