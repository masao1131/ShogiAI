# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %%
import sys
sys.version
# Out:
# '3.10.14 (main, Aug 14 2024, 04:16:06) [MSC v.1929 64 bit (AMD64)]'

# %%
print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 2.3.3
